# %%
#import packages 
import networkx as nx
import json
from networkx.readwrite import json_graph
import matplotlib.pyplot as plt
import numpy as np
import random
import networkx as nx
from collections import deque

# %%
import os
import json
import networkx.readwrite.json_graph as json_graph

# Set the base directory where all the files are stored
base_dir = '/Users/brookefeinberg/SamplingBalancedForests/'

# List of all 50 US state abbreviations
state_abbrs = [
    "ak", "al", "ar", "az", "ca", "co", "ct", "de", "fl", "ga",
    "hi", "ia", "id", "il", "in", "ks", "ky", "la", "ma", "md",
    "me", "mi", "mn", "mo", "ms", "mt", "nc", "nd", "ne", "nh",
    "nj", "nm", "nv", "ny", "oh", "ok", "or", "pa", "ri", "sc",
    "sd", "tn", "tx", "ut", "va", "vt", "wa", "wi", "wv", "wy"
]

# Dictionary to store graph data for each state
state_graphs = {}

# Iterate through each state abbreviation and load the corresponding JSON
for abbr in state_abbrs:
    file_path = os.path.join(base_dir, f'cnty_{abbr}.json')
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            graph = json_graph.adjacency_graph(data)
            state_graphs[abbr] = graph
            print(f"Loaded graph for {abbr.upper()} with {len(graph)} nodes.")
    except FileNotFoundError:
        print(f"File not found for {abbr.upper()}: {file_path}")
    except Exception as e:
        print(f"Error loading {abbr.upper()}: {e}")
# Out:
# Loaded graph for AK with 30 nodes.
# Loaded graph for AL with 67 nodes.
# Loaded graph for AR with 75 nodes.
# Loaded graph for AZ with 15 nodes.
# Loaded graph for CA with 58 nodes.
# Loaded graph for CO with 64 nodes.
# Loaded graph for CT with 8 nodes.
# Loaded graph for DE with 3 nodes.
# Loaded graph for FL with 67 nodes.
# Loaded graph for GA with 159 nodes.
# Loaded graph for HI with 5 nodes.
# Loaded graph for IA with 99 nodes.
# Loaded graph for ID with 44 nodes.
# Loaded graph for IL with 102 nodes.
# Loaded graph for IN with 92 nodes.
# Loaded graph for KS with 105 nodes.
# Loaded graph for KY with 120 nodes.
# Loaded graph for LA with 64 nodes.
# Loaded graph for MA with 14 nodes.
# Loaded graph for MD with 24 nodes.
# Loaded graph for ME with 16 nodes.
# Loaded graph for MI with 83 nodes.
# Loaded graph for MN with 87 nodes.
# Loaded graph for MO with 115 nodes.
# Loaded graph for MS with 82 nodes.
# Loaded graph for MT with 56 nodes.
# Loaded graph for NC with 100 nodes.
# Loaded graph for ND with 53 nodes.
# Loaded graph for NE with 93 nodes.
# Loaded graph for NH with 10 nodes.
# Loaded graph for NJ with 21 nodes.
# Loaded graph for NM with 33 nodes.
# File not found for NV: /Users/brookefeinberg/SamplingBalancedForests/cnty_nv.json
# Loaded graph for NY with 62 nodes.
# Loaded graph for OH with 88 nodes.
# Loaded graph for OK with 77 nodes.
# Loaded graph for OR with 36 nodes.
# Loaded graph for PA with 67 nodes.
# Loaded graph for RI with 5 nodes.
# Loaded graph for SC with 46 nodes.
# Loaded graph for SD with 66 nodes.
# Loaded graph for TN with 95 nodes.
# Loaded graph for TX with 254 nodes.
# Loaded graph for UT with 29 nodes.
# Loaded graph for VA with 133 nodes.
# Loaded graph for VT with 14 nodes.
# Loaded graph for WA with 39 nodes.
# Loaded graph for WI with 72 nodes.
# Loaded graph for WV with 55 nodes.
# Loaded graph for WY with 23 nodes.

# %%
#load cnty data 
file_path = '/Users/brookefeinberg/SamplingBalancedForests/cnty_al.json'
with open(file_path, 'r') as file:
    data = json.load(file)
    cnty = json_graph.adjacency_graph(data)

# %%
#plot 
import matplotlib.pyplot as plt
node_locations = { v : ( float(cnty.nodes()[v]["INTPTLON20"]), float(cnty.nodes()[v]["INTPTLAT20"])) for v in cnty.nodes() }
plt.figure()
nx.draw(cnty, node_size = 10, pos = node_locations)
plt.show()

# %%
#Wilson's Algorithm

class WilsonsAlgorithm:
    def __init__(self, graph):
        self.graph = graph  #store networkX graph 
        self.adj_list = {v: list(graph.neighbors(v)) for v in graph.nodes() if list(graph.neighbors(v))}  #for each graph node return the neighbors and store it as a dictionary where node is the key and each value corresponds to a list of its neighbors 
        self.InTree = {node: False for node in self.adj_list}  #initalizes dictionary to keep track of whether nodes have been included in the spanning tree -- FALSE as initial value menaing node has yet to be included in the tree 
        self.Next = {node: None for node in self.adj_list}  #initalizes dictionary to track path each node takes in a random walk 
    
    def random_edge(self, v): #randomly selects an edge for a given node v 
        return random.choice(self.adj_list[v]) #retrieves the list of neighbors for node v in the adjacency list and randomly picks one -- simulating step ina  random walk 

    def RandomTreeWithRoot(self, r): #generate random spanning tree with r as the root node 
        self.InTree = {node: False for node in self.adj_list} #initalize all nodes as not in the spanning tree 
        self.InTree[r] = True  #mark root node as in the tree 
        self.Next[r] = -1  #root node has no parent aka no incoming edges 

        for node in self.adj_list: #loops through each nodein the graph, attempting to find a path to the root using a random walk 
            path = []  
            while not self.InTree[node]: #loop continues as long as node is not already in the spanning tree 
                path.append(node)  #record each step of the random walk 
                self.Next[node] = self.random_edge(node) #choose a random neighbor & record it as the next step in the walk (connects node to its next random neighbor in the path)
                node = self.Next[node]  #update next node and the new node so the loop continues till we reach a node already in the spanning tree 
            for vertex in path:  #loop has broken bc we've reached a node already part of the spanning tree 
                self.InTree[vertex] = True  #adds each vertex to the spanning tree from the root outward 

    def sample(self, seed=None):
        if seed is not None: #can include seed later on for reproducible results 
            random.seed(seed)
        root = random.choice(list(self.adj_list.keys()))  #picks a random node to be a root 
        self.RandomTreeWithRoot(root) #builds ranodm spannign tree with the ranodm root chosen 

        spanning_tree = []  #extract edges of spannign tree for plotting 
        for node in self.adj_list: 
            if self.Next[node] != -1 and self.Next[node] is not None: #find nodes connected to another node in the tree 
                spanning_tree.append((node, self.Next[node])) #addes connection or edge as a tuple of two nodes to the spanning tree list 
        return spanning_tree, root #returns all the edges in the form of (node1, node2) and the root node 

    def draw_tree(self, spanning_tree, root, node_locations): #plot the spanning tree on the graph
        plt.figure(figsize=(8, 8))
        nx.draw(self.graph, pos=node_locations, node_size=10, edge_color='lightgray') #draw original graph 
        nx.draw_networkx_edges(self.graph, pos=node_locations, edgelist=spanning_tree, edge_color='red', width=2) #draw spanning tree 
        nx.draw_networkx_nodes(self.graph, pos=node_locations, nodelist=[root], node_color='yellow', node_size=50)  #draw root node 
        plt.show()

# %%
#BFS Graph Partitioner 
class GraphPartitioner:
    def __init__(self, graph, k):
        self.graph = graph
        self.k = k

    def create_weighted_partitions_and_draw_spanning_tree(self):
        while True:
            wilson = WilsonsAlgorithm(self.graph) #generate random spannign tree using wilson's algorithm 
            spanning_tree, root = wilson.sample() 

            tree_graph = nx.Graph() 
            tree_graph.add_edges_from(spanning_tree)  #take edges form spannign tree and add them to the new graph

            total_nodes = len(tree_graph) 
            ideal_size = total_nodes // self.k
            extra_nodes = total_nodes % self.k
            target_sizes = [ideal_size + 1 if i < extra_nodes else ideal_size for i in range(self.k)] #accomedate odd nodes 

            partitions = [[] for _ in range(self.k)] # initalize BFS queues 
            partition_sizes = [0] * self.k
            bfs_queues = [deque([root])] + [deque() for _ in range(self.k - 1)] 

            visited = set([root])
            partitions[0].append(root)
            partition_sizes[0] += 1

            for current_partition in range(self.k):
                while partition_sizes[current_partition] < target_sizes[current_partition] and bfs_queues[current_partition]:
                    node = bfs_queues[current_partition].popleft()
                    for neighbor in tree_graph.neighbors(node):
                        if neighbor not in visited:
                            partitions[current_partition].append(neighbor)
                            partition_sizes[current_partition] += 1
                            visited.add(neighbor)
                            bfs_queues[current_partition].append(neighbor)
                            if partition_sizes[current_partition] >= target_sizes[current_partition]:
                                break
                            
                # check if partition has reached the right size--else continue the loop for a new tree            
                if partition_sizes[current_partition] < target_sizes[current_partition]:
                    #print("Attempt failed, generating a new spanning tree.")
                    return False          #initalizae for statistical inference 
                    #break  

                # initalize next partition with an unvisited node 
                unvisited_nodes = [n for n in tree_graph.nodes if n not in visited]
                if unvisited_nodes and current_partition + 1 < self.k:
                    seed_node = unvisited_nodes[0]
                    partitions[current_partition + 1].append(seed_node)
                    partition_sizes[current_partition + 1] += 1
                    visited.add(seed_node)
                    bfs_queues[current_partition + 1].append(seed_node)

            # check if all partitions are the right size
            if all(partition_sizes[i] == target_sizes[i] for i in range(self.k)):
                #print("Balanced partitions found.")
                return True
                #break
              
        # Step 3: Plotting 
        node_locations = {v: (float(cnty.nodes()[v]["INTPTLON20"]) - 360 if float(cnty.nodes()[v]["INTPTLON20"]) > 0 else float(cnty.nodes()[v]["INTPTLON20"]),
        float(cnty.nodes()[v]["INTPTLAT20"]))for v in cnty.nodes()}
        pos = node_locations
        plt.figure(figsize=(10, 10))
        base_colors = ['blue', 'green']
        spanning_tree_pos = {node: pos[node] for node in tree_graph.nodes}
        for i, partition in enumerate(partitions):
            nx.draw_networkx_nodes(tree_graph, spanning_tree_pos, nodelist=partition, node_size=50,
                                   node_color=base_colors[i % len(base_colors)], label=f'Partition {i+1}')
        nx.draw_networkx_edges(tree_graph, spanning_tree_pos, edge_color='gray', width=2)
        plt.legend()
        plt.title("Spanning Tree with Weighted, Connected, Balanced Partitions")
        plt.show()
        return True


G = cnty  
k = 3 
partitioner = GraphPartitioner(G, k)
partitioner.create_weighted_partitions_and_draw_spanning_tree()
# Out:
# False

# %%
def run_partition_simulations(graph, p, k):
    successful_splits = 0
    trials = 0

    while successful_splits < k:
        trials += 1
        partitioner = GraphPartitioner(graph, p)
        
        if partitioner.create_weighted_partitions_and_draw_spanning_tree():
            successful_splits += 1

    success_rate= (k/trials)*100

    print(f"It took {trials} trials to achieve {k} successful splits for {p} partitions.")
    print(f"average success rate is {success_rate}")


run_partition_simulations(cnty, p=4, k=178)
# Out:
# It took 899707 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.01978421864006838

# %%
import os
import json
import networkx.readwrite.json_graph as json_graph

# Set the base directory where all the files are stored
base_dir = '/Users/brookefeinberg/SamplingBalancedForests/'

# List of all 50 US state abbreviations
state_abbrs = [
    "al", "ar", "az", "ca", "co", "ct", "de", "fl", "ga",
    "hi", "ia", "id", "il", "in", "ks", "ky", "la", "ma", "md",
    "me", "mi", "mn", "mo", "ms", "mt", "nc", "nd", "ne", "nh",
    "nj", "nm", "nv", "ny", "oh", "ok", "or", "pa", "ri", "sc",
    "sd", "tn", "tx", "ut", "va", "vt", "wa", "wi", "wv", "wy"
]

# Dictionary to store graph data for each state
state_graphs = {}

# Iterate through each state abbreviation and load the corresponding JSON
for abbr in state_abbrs:
    file_path = os.path.join(base_dir, f'cnty_{abbr}.json')
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            graph = json_graph.adjacency_graph(data)
            state_graphs[abbr] = graph
            print(f"Loaded graph for {abbr.upper()} with {len(graph)} nodes.")
    except FileNotFoundError:
        print(f"File not found for {abbr.upper()}: {file_path}")
    except Exception as e:
        print(f"Error loading {abbr.upper()}: {e}")
# Out:
# Loaded graph for AL with 67 nodes.
# Loaded graph for AR with 75 nodes.
# Loaded graph for AZ with 15 nodes.
# Loaded graph for CA with 58 nodes.
# Loaded graph for CO with 64 nodes.
# Loaded graph for CT with 8 nodes.
# Loaded graph for DE with 3 nodes.
# Loaded graph for FL with 67 nodes.
# Loaded graph for GA with 159 nodes.
# Loaded graph for HI with 5 nodes.
# Loaded graph for IA with 99 nodes.
# Loaded graph for ID with 44 nodes.
# Loaded graph for IL with 102 nodes.
# Loaded graph for IN with 92 nodes.
# Loaded graph for KS with 105 nodes.
# Loaded graph for KY with 120 nodes.
# Loaded graph for LA with 64 nodes.
# Loaded graph for MA with 14 nodes.
# Loaded graph for MD with 24 nodes.
# Loaded graph for ME with 16 nodes.
# Loaded graph for MI with 83 nodes.
# Loaded graph for MN with 87 nodes.
# Loaded graph for MO with 115 nodes.
# Loaded graph for MS with 82 nodes.
# Loaded graph for MT with 56 nodes.
# Loaded graph for NC with 100 nodes.
# Loaded graph for ND with 53 nodes.
# Loaded graph for NE with 93 nodes.
# Loaded graph for NH with 10 nodes.
# Loaded graph for NJ with 21 nodes.
# Loaded graph for NM with 33 nodes.
# File not found for NV: /Users/brookefeinberg/SamplingBalancedForests/cnty_nv.json
# Loaded graph for NY with 62 nodes.
# Loaded graph for OH with 88 nodes.
# Loaded graph for OK with 77 nodes.
# Loaded graph for OR with 36 nodes.
# Loaded graph for PA with 67 nodes.
# Loaded graph for RI with 5 nodes.
# Loaded graph for SC with 46 nodes.
# Loaded graph for SD with 66 nodes.
# Loaded graph for TN with 95 nodes.
# Loaded graph for TX with 254 nodes.
# Loaded graph for UT with 29 nodes.
# Loaded graph for VA with 133 nodes.
# Loaded graph for VT with 14 nodes.
# Loaded graph for WA with 39 nodes.
# Loaded graph for WI with 72 nodes.
# Loaded graph for WV with 55 nodes.
# Loaded graph for WY with 23 nodes.

# %%
def run_partition_simulationsss(graph, p, k):
    successful_splits = 0
    trials = 0

    while successful_splits < k:
        trials += 1
        partitioner = GraphPartitioner(graph, p)
        
        if partitioner.create_weighted_partitions_and_draw_spanning_tree():
            successful_splits += 1

    success_rate = (k / trials) * 100
    return trials, success_rate


# Run partition simulations for all 50 states
p = 4  # Number of partitions
k = 178  # Number of successful splits to target

results = {}  # Store results for each state

for abbr, graph in state_graphs.items():
    print(f"\nRunning simulations for {abbr.upper()}")
    try:
        trials, success_rate = run_partition_simulations(graph, p, k)
        results[abbr] = {
            "trials": trials,
            "success_rate": success_rate
        }
        print(f"{abbr.upper()}: Took {trials} trials → Success Rate: {success_rate:.2f}%")
    except Exception as e:
        print(f"Error running partition simulations for {abbr.upper()}: {e}")
# Out:
# Running simulations for AL
# It took 726992 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.02448445099808526
# Error running partition simulations for AL: cannot unpack non-iterable NoneType object
#
# Running simulations for AR
# It took 786110 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.02264314154507639
# Error running partition simulations for AR: cannot unpack non-iterable NoneType object
#
# Running simulations for AZ
# It took 6192 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 2.8746770025839794
# Error running partition simulations for AZ: cannot unpack non-iterable NoneType object
#
# Running simulations for CA
# It took 496384 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.03585933470861269
# Error running partition simulations for CA: cannot unpack non-iterable NoneType object
#
# Running simulations for CO
# It took 632110 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.028159655756118396
# Error running partition simulations for CO: cannot unpack non-iterable NoneType object
#
# Running simulations for CT
# It took 914 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 19.474835886214443
# Error running partition simulations for CT: cannot unpack non-iterable NoneType object
#
# Running simulations for DE
# It took 178 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 100.0
# Error running partition simulations for DE: cannot unpack non-iterable NoneType object
#
# Running simulations for FL
# It took 352943 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.0504330727624574
# Error running partition simulations for FL: cannot unpack non-iterable NoneType object
#
# Running simulations for GA
# It took 12427386 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.0014323205217895382
# Error running partition simulations for GA: cannot unpack non-iterable NoneType object
#
# Running simulations for HI
# It took 178 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 100.0
# Error running partition simulations for HI: cannot unpack non-iterable NoneType object
#
# Running simulations for IA
# It took 2572039 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.006920579353579009
# Error running partition simulations for IA: cannot unpack non-iterable NoneType object
#
# Running simulations for ID
# It took 220342 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.08078350927194997
# Error running partition simulations for ID: cannot unpack non-iterable NoneType object
#
# Running simulations for IL
# It took 2822741 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.00630592746553793
# Error running partition simulations for IL: cannot unpack non-iterable NoneType object
#
# Running simulations for IN
# It took 2592796 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.0068651756636465035
# Error running partition simulations for IN: cannot unpack non-iterable NoneType object
#
# Running simulations for KS
# It took 2712479 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.00656226278618194
# Error running partition simulations for KS: cannot unpack non-iterable NoneType object
#
# Running simulations for KY
# It took 3727183 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.004775724722934184
# Error running partition simulations for KY: cannot unpack non-iterable NoneType object
#
# Running simulations for LA
# It took 551743 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.03226139706348789
# Error running partition simulations for LA: cannot unpack non-iterable NoneType object
#
# Running simulations for MA
# It took 4429 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 4.0189659065251755
# Error running partition simulations for MA: cannot unpack non-iterable NoneType object
#
# Running simulations for MD
# It took 68132 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.2612575588563377
# Error running partition simulations for MD: cannot unpack non-iterable NoneType object
#
# Running simulations for ME
# It took 7487 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 2.3774542540403365
# Error running partition simulations for ME: cannot unpack non-iterable NoneType object
#
# Running simulations for MI
# It took 1959678 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.0090831248807202
# Error running partition simulations for MI: cannot unpack non-iterable NoneType object
#
# Running simulations for MN
# It took 1950086 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.009127802568707226
# Error running partition simulations for MN: cannot unpack non-iterable NoneType object
#
# Running simulations for MO
# It took 4192662 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.00424551275538071
# Error running partition simulations for MO: cannot unpack non-iterable NoneType object
#
# Running simulations for MS
# It took 2082370 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.00854795257326988
# Error running partition simulations for MS: cannot unpack non-iterable NoneType object
#
# Running simulations for MT
# It took 420753 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.04230510537060936
# Error running partition simulations for MT: cannot unpack non-iterable NoneType object
#
# Running simulations for NC
# It took 3419740 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.005205074069958535
# Error running partition simulations for NC: cannot unpack non-iterable NoneType object
#
# Running simulations for ND
# It took 318714 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.05584944495692063
# Error running partition simulations for ND: cannot unpack non-iterable NoneType object
#
# Running simulations for NE
# It took 1878050 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.009477915923431219
# Error running partition simulations for NE: cannot unpack non-iterable NoneType object
#
# Running simulations for NH
# It took 1444 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 12.326869806094184
# Error running partition simulations for NH: cannot unpack non-iterable NoneType object
#
# Running simulations for NJ
# It took 12754 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 1.3956405833464012
# Error running partition simulations for NJ: cannot unpack non-iterable NoneType object
#
# Running simulations for NM
# It took 73084 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.24355536095451807
# Error running partition simulations for NM: cannot unpack non-iterable NoneType object
#
# Running simulations for NY
# It took 277942 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.06404213828784422
# Error running partition simulations for NY: cannot unpack non-iterable NoneType object
#
# Running simulations for OH
# It took 2575624 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.006910946628855765
# Error running partition simulations for OH: cannot unpack non-iterable NoneType object
#
# Running simulations for OK
# It took 1281835 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.013886342626001007
# Error running partition simulations for OK: cannot unpack non-iterable NoneType object
#
# Running simulations for OR
# It took 93875 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.1896138482023968
# Error running partition simulations for OR: cannot unpack non-iterable NoneType object
#
# Running simulations for PA
# It took 1246748 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.014277143416311876
# Error running partition simulations for PA: cannot unpack non-iterable NoneType object
#
# Running simulations for RI
# It took 178 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 100.0
# Error running partition simulations for RI: cannot unpack non-iterable NoneType object
#
# Running simulations for SC
# It took 272171 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.06540006099106811
# Error running partition simulations for SC: cannot unpack non-iterable NoneType object
#
# Running simulations for SD
# It took 571964 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.031120839773132573
# Error running partition simulations for SD: cannot unpack non-iterable NoneType object
#
# Running simulations for TN
# It took 1525501 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.011668297824780188
# Error running partition simulations for TN: cannot unpack non-iterable NoneType object
#
# Running simulations for TX
# It took 106096504 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.0001677717863352029
# Error running partition simulations for TX: cannot unpack non-iterable NoneType object
#
# Running simulations for UT
# It took 26907 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.6615378897684617
# Error running partition simulations for UT: cannot unpack non-iterable NoneType object
#
# Running simulations for VA
# It took 11861112 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.0015007024636475906
# Error running partition simulations for VA: cannot unpack non-iterable NoneType object
#
# Running simulations for VT
# It took 3647 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 4.880723882643268
# Error running partition simulations for VT: cannot unpack non-iterable NoneType object
#
# Running simulations for WA
# It took 119776 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.14861074004808977
# Error running partition simulations for WA: cannot unpack non-iterable NoneType object
#
# Running simulations for WI
# It took 881136 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.020201194821230777
# Error running partition simulations for WI: cannot unpack non-iterable NoneType object
#
# Running simulations for WV
# It took 632363 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.028148389453525904
# Error running partition simulations for WV: cannot unpack non-iterable NoneType object
#
# Running simulations for WY
# It took 24155 trials to achieve 178 successful splits for 4 partitions.
# average success rate is 0.7369074725729663
# Error running partition simulations for WY: cannot unpack non-iterable NoneType object
