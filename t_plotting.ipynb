# %%
#t data 
graph_data = {
    "westvirginia": {
        "avg_success_rate": 0.0010,
        "nodes": 546,
        "total_time": "6m 19.5s",
        "num_trials": 176358
    },
    "wyoming": {
        "avg_success_rate": 0.0026,
        "nodes": 160,
        "total_time": "28.0s",
        "num_trials": 68070
    },
    "vermont": {
        "avg_success_rate": 0.0057,
        "nodes": 193,
        "total_time": "16.1s",
        "num_trials": 31266
    },
    "washington": {
        "avg_success_rate": 0.0002,
        "nodes": 1784,
        "total_time": "97m 48.2s",
        "num_trials": 821861
    },
    "virginia": {
        "avg_success_rate": 0.0001,
        "nodes": 2198,
        "total_time": "342m 25.6s",
        "num_trials": 1613429
    },
    "southcarolina": {
        "avg_success_rate": 0.0007,
        "nodes": 1323,
        "total_time": "18m 22.4s",
        "num_trials": 245515
    },
    "utah": {
        "avg_success_rate": 0.0008,
        "nodes": 716,
        "total_time": "7m 42.1s",
        "num_trials": 213041
    },
    "tennesse": {
        "avg_success_rate": 0.0005,
        "nodes": 1701,
        "total_time": "58m 32.3s",
        "num_trials": 335645
    },
    "oklahoma": {
        "avg_success_rate": 0.0005,
        "nodes": 1205,
        "total_time": "23m 42.7s",
        "num_trials": 353748
    },
    "southdakota": {
        "avg_success_rate": 0.0031,
        "nodes": 242,
        "total_time": "39.0s",
        "num_trials": 58107
    },
    "pennsylvannia": {
        "avg_success_rate": 0.0002,
        "nodes": 3446,
        "total_time": "237m 44.8s",
        "num_trials": 756212
    },
    "ohio": {
        "avg_success_rate": 0.0002,
        "nodes": 3168,
        "total_time": "235m 50.5s",
        "num_trials": 908068
    },
    "oregon": {
        "avg_success_rate": 0.0007,
        "nodes": 1001,
        "total_time": "14m 30.7s",
        "num_trials": 261731
    },
    "newyork": {
        "avg_success_rate": 0.0002,
        "nodes": 5411,
        "total_time": "944m 59.1s",
        "num_trials": 901907
    },
    "newmexico": {
        "avg_success_rate": 0.0007,
        "nodes": 612,
        "total_time": "8m 21.2s",
        "num_trials": 265269
    },
    "newjersey": {
        "avg_success_rate": 0.0005,
        "nodes": 2181,
        "total_time": "88m 41.1s",
        "num_trials": 349784
    },
    "newhampshire": {
        "avg_success_rate": 0.0033,
        "nodes": 350,
        "total_time": "55.9s",
        "num_trials": 54154
    },
    "michigan": {
        "avg_success_rate": 0.0003,
        "nodes": 3017,
        "total_time": "184m 20.1s",
        "num_trials": 549963
    },
    "northdakota": {
        "avg_success_rate": 0.0026,
        "nodes": 228,
        "total_time": "48.0s",
        "num_trials": 69484
    },
    "northcarolina": {
        "avg_success_rate": 0.0004,
        "nodes": 2672,
        "total_time": "227m 44.9s",
        "num_trials": 454677
    },
    "montana": {
        "avg_success_rate": 0.0011,
        "nodes": 319,
        "total_time": "2m 27.3s",
        "num_trials": 163357
    },
    "mississippi": {
        "avg_success_rate": 0.0009,
        "nodes": 878,
        "total_time": "10m 36.6s",
        "num_trials": 190873
    },
    "missouri": {
        "avg_success_rate": 0.0004,
        "nodes": 1654,
        "total_time": "142m 22.7s",
        "num_trials": 507063
    },
    "minnesota": {
        "avg_success_rate": 0.0006,
        "nodes": 1505,
        "total_time": "36m 27.4s",
        "num_trials": 297168
    },
    "maine": {
        "avg_success_rate": 0.0038,
        "nodes": 407,
        "total_time": "58.4s",
        "num_trials": 46306
    },
    "maryland": {
        "avg_success_rate": 0.0005,
        "nodes": 1475,
        "total_time": "70m 7.6s",
        "num_trials": 338873
    },
    "kansas": {
        "avg_success_rate": 0.0007,
        "nodes": 829,
        "total_time": "18m 53.0s",
        "num_trials": 266398
    },
    "massachusetts": {
        "avg_success_rate": 0.0005,
        "nodes": 1620,
        "total_time": "110m 30.0s",
        "num_trials": 374138
    },
    "louisiana": {
        "avg_success_rate": 0.0006,
        "nodes": 1388,
        "total_time": "47m 54.4s",
        "num_trials": 309439
    },
    "kentucky": {
        "avg_success_rate": 0.0005,
        "nodes": 1306,
        "total_time": "83m 24.2s",
        "num_trials": 368659
    },
    "indiana": {
        "avg_success_rate": 0.0003,
        "nodes": 1696,
        "total_time": "185m 38.3s",
        "num_trials": 526589
    },
    "illinois": {
        "avg_success_rate": 0.0003,
        "nodes": 3265,
        "total_time": "448m 30.7s",
        "num_trials": 706879
    },
    "iowa": {
        "avg_success_rate": 0.0007,
        "nodes": 896,
        "total_time": "26m 52.1s",
        "num_trials": 264011
    },
    "idaho": {
        "avg_success_rate": 0.0006,
        "nodes": 456,
        "total_time": "13m 43.8s",
        "num_trials": 285610
    },
    "georgia": {
        "avg_success_rate": 0.0003,
        "nodes": 2796,
        "total_time": "338m 29.3s",
        "num_trials": 565110
    },
    "deleware": {
        "avg_success_rate": 0.0034,
        "nodes": 262,
        "total_time": "1m 9.1s",
        "num_trials": 52403
    },
    "conneticut": {
        "avg_success_rate": 0.0011,
        "nodes": 883,
        "total_time": "17m 34.9s",
        "num_trials": 168745
    },
    "colorado": {
        "avg_success_rate": 0.0006,
        "nodes": 1447,
        "total_time": "103m 53.2s",
        "num_trials": 319490
    },
    "arkansas": {
        "avg_success_rate": 0.0007,
        "nodes": 823,
        "total_time": "26m 18.8s",
        "num_trials": 247009
    },
    "arizonia": {
        "avg_success_rate": 0.0003,
        "nodes": 1765,
        "total_time": "199m 58.0s",
        "num_trials": 556419
    },
    "alabama": {
        "avg_success_rate": 0.0006,
        "nodes": 1437,
        "total_time": "114m 19.7s",
        "num_trials": 321179
    },
    "alaska": {
        "avg_success_rate": 0.0025,
        "nodes": 177,
        "total_time": "1m 41.2s",
        "num_trials": 71782
    }
}

# %%
#import packages 
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from sklearn.metrics import mean_squared_error, r2_score

# %%
#counties vs success rate

#extarct data
counties = [state_data["nodes"] for state_data in graph_data.values()]
avg_success_rates = [state_data["avg_success_rate"] for state_data in graph_data.values()]
states = list(graph_data.keys())

#plot figure
plt.figure(figsize=(10, 6))
plt.scatter(counties, avg_success_rates)

plt.xlabel("Number of Counties")
plt.ylabel("Average Success Rate (%)")
plt.title("Average Success Rate vs. Number of Counties")

for i, state in enumerate(states):
    plt.annotate(state, (counties[i], avg_success_rates[i]), fontsize=8, alpha=0.7)

plt.show()

# %% [markdown]
# $ln(x)=y$ such that $e^x = y$

# %%
#LOG TRANSFORM - counties vs success rate

#extarct data
counties = [state_data["nodes"] for state_data in graph_data.values()]
avg_success_rates = [state_data["avg_success_rate"] for state_data in graph_data.values()]
states = list(graph_data.keys())

#apply log transformations 
log_counties = np.log(counties)
log_avg_success_rates = np.log(avg_success_rates)

#create log-log plot 
plt.figure(figsize=(10, 6))
plt.scatter(log_counties, log_avg_success_rates) #ASK ABOUT THE +10 FOR MAKING IT POSITIVE 

plt.xlabel("Log(Number of Counties)")
plt.ylabel("Log(Average Success Rate (%))")
plt.title("Log-Log Plot of Average Success Rate vs. Number of Counties")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import mean_squared_error, r2_score

def inverse_exponential(x, a, b, c):
    return a * np.exp(-b * x) + c

def power_law(x, a, b):
    return a * np.log(x) +b

def linear_model(x, m, c):
    return m * x + c

avg_success_rates = np.array(avg_success_rates)
counties = np.array(counties)

valid_indices = avg_success_rates > 0
filtered_counties = counties[valid_indices]
filtered_avg_success_rates = avg_success_rates[valid_indices]

log_filtered_counties = np.log(filtered_counties)
log_filtered_avg_success_rates = np.log(filtered_avg_success_rates)

valid_log_indices = np.isfinite(log_filtered_counties) & np.isfinite(log_filtered_avg_success_rates)
log_filtered_counties = log_filtered_counties[valid_log_indices]
log_filtered_avg_success_rates = log_filtered_avg_success_rates[valid_log_indices]

initial_guess_exp = [1, 0.1, 0]
initial_guess_poly = [1, 1]
initial_guess_linear = [1, 0]

params_exp_log, _ = curve_fit(inverse_exponential, log_filtered_counties, log_filtered_avg_success_rates,
                                  p0=initial_guess_exp, maxfev=10000)
a_exp_log, b_exp_log, c_exp_log = params_exp_log

params_power_log, _ = curve_fit(power_law, log_filtered_counties, log_filtered_avg_success_rates,
                                    p0=initial_guess_poly, maxfev=10000)
log_c_power, b_power = params_power_log
c_power = np.exp(log_c_power)

params_linear, _ = curve_fit(linear_model, log_filtered_counties, log_filtered_avg_success_rates,
                                 p0=initial_guess_linear, maxfev=10000)
m_linear, c_linear = params_linear


pred_exp_log = inverse_exponential(log_filtered_counties, a_exp_log, b_exp_log, c_exp_log)
pred_power_log = power_law(log_filtered_counties, log_c_power, b_power)
pred_linear = linear_model(log_filtered_counties, m_linear, c_linear)

mse_exp_log = mean_squared_error(log_filtered_avg_success_rates, pred_exp_log)
mse_power_log = mean_squared_error(log_filtered_avg_success_rates, pred_power_log)
mse_linear = mean_squared_error(log_filtered_avg_success_rates, pred_linear)

r2_exp_log = r2_score(log_filtered_avg_success_rates, pred_exp_log)
r2_power_log = r2_score(log_filtered_avg_success_rates, pred_power_log)
r2_linear = r2_score(log_filtered_avg_success_rates, pred_linear)

print(f"Log-Log Inverse Exponential Model:")
print(f"Formula: ln(y) = ln({a_exp_log:.4f}) - {b_exp_log:.4f} * x + {c_exp_log:.4f}")
print(f"Original formula: y = {a_exp_log:.4f} * exp(-{b_exp_log:.4f} * x) + {c_exp_log:.4f}")
print(f"MSE = {mse_exp_log:.4f}, R^2 = {r2_exp_log:.4f}\n")

print(f"Log-Log Power Law Model:")
print(f"Formula: ln(y) = ln({c_power:.4f}) - {b_power:.4f} * ln(x)")
print(f"Original formula: y = {c_power:.4f} / x^{b_power:.4f}")
print(f"MSE = {mse_power_log:.4f}, R^2 = {r2_power_log:.4f}\n")

print(f"Log-Log Linear Model:")
print(f"Formula: ln(y) = {m_linear:.4f} * x + {c_linear:.4f}")
print(f"MSE = {mse_linear:.4f}, R^2 = {r2_linear:.4f}\n")

x_vals_log = np.linspace(min(log_filtered_counties), max(log_filtered_counties), 500)
y_vals_exp_log = inverse_exponential(x_vals_log, a_exp_log, b_exp_log, c_exp_log)
y_vals_power_log = power_law(x_vals_log, log_c_power, b_power)
y_vals_linear = linear_model(x_vals_log, m_linear, c_linear)

plt.figure(figsize=(10, 6))
plt.scatter(log_filtered_counties, log_filtered_avg_success_rates, color='blue', label="Log-Log Data Points")
plt.plot(x_vals_log, y_vals_exp_log, "r--", label="Log-Log Inverse Exponential Fit")
plt.plot(x_vals_log, y_vals_power_log, "g--", label="Log-Log Power Law Fit")
plt.plot(x_vals_log, y_vals_linear, "b--", label="Log-Log Linear Fit")

plt.xlabel("Log(Number of Counties)")
plt.ylabel("Log(Average Success Rate)")
plt.title("Log-Log Model Comparisons")
plt.legend()
plt.show()
# Out:
# Log-Log Inverse Exponential Model:
# Formula: ln(y) = ln(18.3153) - 0.0943 * x + -16.8665
# Original formula: y = 18.3153 * exp(-0.0943 * x) + -16.8665
# MSE = 0.1520, R^2 = 0.8182
#
# Log-Log Power Law Model:
# Formula: ln(y) = ln(0.0023) - 4.4092 * ln(x)
# Original formula: y = 0.0023 / x^4.4092
# MSE = 0.1528, R^2 = 0.8172
#
# Log-Log Linear Model:
# Formula: ln(y) = -0.9196 * x + -0.9343
# MSE = 0.1534, R^2 = 0.8164

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import mean_squared_error, r2_score

def inverse_exponential(x, a, b, c):
    return a * np.exp(-b * x) + c

def inverse_polynomial(x, c, b, a):
    return (c / (x ** b)) + a

def linear_model(x, m, c):
    return m * x + c

avg_success_rates = np.array(avg_success_rates)
counties = np.array(counties)

#filter out success rate less than 0 
valid_indices = avg_success_rates > 0
filtered_counties = counties[valid_indices]
filtered_avg_success_rates = avg_success_rates[valid_indices]

log_filtered_counties = np.log(filtered_counties)
log_filtered_avg_success_rates = np.log(filtered_avg_success_rates)

initial_guess_exp = [1, 0.1, 0]
initial_guess_poly = [1, 1, 0]
initial_guess_linear = [1, 0]

params_exp_log, _ = curve_fit(inverse_exponential, log_filtered_counties, log_filtered_avg_success_rates,
                                  p0=initial_guess_exp, maxfev=10000)
a_exp_log, b_exp_log, c_exp_log = params_exp_log

params_poly_log, _ = curve_fit(inverse_polynomial, log_filtered_counties, log_filtered_avg_success_rates,
                                    p0=initial_guess_poly, maxfev=10000)
c_poly_log, b_poly_log, a_poly_log = params_poly_log

params_linear, _ = curve_fit(linear_model, log_filtered_counties, log_filtered_avg_success_rates,
                                 p0=initial_guess_linear, maxfev=10000)
m_linear, c_linear = params_linear


pred_exp_log = inverse_exponential(log_filtered_counties, a_exp_log, b_exp_log, c_exp_log)
pred_poly_log = inverse_polynomial(log_filtered_counties, c_poly_log, b_poly_log, a_poly_log)
pred_linear = linear_model(log_filtered_counties, m_linear, c_linear)

mse_exp_log = mean_squared_error(log_filtered_avg_success_rates, pred_exp_log)
mse_poly_log = mean_squared_error(log_filtered_avg_success_rates, pred_poly_log)
mse_linear = mean_squared_error(log_filtered_avg_success_rates, pred_linear)

r2_exp_log = r2_score(log_filtered_avg_success_rates, pred_exp_log)
r2_poly_log = r2_score(log_filtered_avg_success_rates, pred_poly_log)
r2_linear = r2_score(log_filtered_avg_success_rates, pred_linear)

print(f"Log-Log Inverse Exponential Model:")
print(f"Original formula: y = {a_exp_log:.4f} * exp(-{b_exp_log:.4f} * x) + {c_exp_log:.4f}")
print(f"MSE = {mse_exp_log:.4f}, R^2 = {r2_exp_log:.4f}\n")

print(f"Log-Log Inverse Polynomial Model:")
print(f"Original formula: y = ({c_poly_log:.4f} / x^{b_poly_log:.4f}) + {a_poly_log:.4f}")
print(f"MSE = {mse_poly_log:.4f}, R^2 = {r2_poly_log:.4f}\n")

print(f"Log-Log Linear Model:")
print(f"Formula: ln(y) = {m_linear:.4f} * x + {c_linear:.4f}")
print(f"MSE = {mse_linear:.4f}, R^2 = {r2_linear:.4f}\n")

x_vals_log = np.linspace(min(log_filtered_counties), max(log_filtered_counties), 500)
y_vals_exp_log = inverse_exponential(x_vals_log, a_exp_log, b_exp_log, c_exp_log)
y_vals_poly_log = inverse_polynomial(x_vals_log, c_poly_log, b_poly_log, a_poly_log)
y_vals_linear = linear_model(x_vals_log, m_linear, c_linear)

plt.figure(figsize=(10, 6))
plt.scatter(log_filtered_counties, log_filtered_avg_success_rates, color='blue', label="Log-Log Data Points")
plt.plot(x_vals_log, y_vals_exp_log, "r--", label="Log-Log Inverse Exponential Fit")
plt.plot(x_vals_log, y_vals_poly_log, "g--", label="Log-Log Inverse Polynomial Fit")
plt.plot(x_vals_log, y_vals_linear, "b--", label="Log-Log Linear Fit")

plt.xlabel("Log(Number of Counties)")
plt.ylabel("Log(Average Success Rate)")
plt.title("Log-Log Model Comparisons")
plt.legend()
plt.show()
# Out:
# Log-Log Inverse Exponential Model:
# Original formula: y = 18.3153 * exp(-0.0943 * x) + -16.8665
# MSE = 0.1520, R^2 = 0.8182
#
# Log-Log Inverse Polynomial Model:
# Original formula: y = (-5.7564 / x^24.9904) + -7.2918
# MSE = 0.8358, R^2 = 0.0000
#
# Log-Log Linear Model:
# Formula: ln(y) = -0.9196 * x + -0.9343
# MSE = 0.1534, R^2 = 0.8164
# /var/folders/t1/h9s22qms3r9080_ljhqwn8z40000gn/T/ipykernel_43513/1335642716.py:37: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_poly_log, _ = curve_fit(inverse_polynomial, log_filtered_counties, log_filtered_avg_success_rates,

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import mean_squared_error, r2_score

def inverse_exponential(x, a, b, c):
    return a * np.exp(-b * x) + c

def power_law(x, a, b):
    return a * np.log(x) + b

def linear_model(x, m, c):
    return m * x + c

avg_success_rates = np.array(avg_success_rates)
counties = np.array(counties)

valid_indices = avg_success_rates > 0
filtered_counties = counties[valid_indices]
filtered_avg_success_rates = avg_success_rates[valid_indices]

log_filtered_counties = np.log(filtered_counties)
log_filtered_avg_success_rates = np.log(filtered_avg_success_rates)

valid_log_indices = np.isfinite(log_filtered_counties) & np.isfinite(log_filtered_avg_success_rates)
log_filtered_counties = log_filtered_counties[valid_log_indices]
log_filtered_avg_success_rates = log_filtered_avg_success_rates[valid_log_indices]

initial_guess_exp = [1, 0.1, 0]
initial_guess_poly = [1, 1, 0]
initial_guess_power = [1, 1]
initial_guess_linear = [1, 0]

params_exp_log, _ = curve_fit(inverse_exponential, log_filtered_counties, log_filtered_avg_success_rates,
                                  p0=initial_guess_exp, maxfev=10000)
a_exp_log, b_exp_log, c_exp_log = params_exp_log

params_power_log, _ = curve_fit(power_law, log_filtered_counties, log_filtered_avg_success_rates,
                                    p0=initial_guess_power, maxfev=10000)
a_power_log, b_power_log = params_power_log

params_linear, _ = curve_fit(linear_model, log_filtered_counties, log_filtered_avg_success_rates,
                                 p0=initial_guess_linear, maxfev=10000)
m_linear, c_linear = params_linear

pred_exp_log = inverse_exponential(log_filtered_counties, a_exp_log, b_exp_log, c_exp_log)
pred_power_log = power_law(log_filtered_counties, a_power_log, b_power_log)
pred_linear = linear_model(log_filtered_counties, m_linear, c_linear)

mse_exp_log = mean_squared_error(log_filtered_avg_success_rates, pred_exp_log)
mse_power_log = mean_squared_error(log_filtered_avg_success_rates, pred_power_log)
mse_linear = mean_squared_error(log_filtered_avg_success_rates, pred_linear)

r2_exp_log = r2_score(log_filtered_avg_success_rates, pred_exp_log)
r2_power_log = r2_score(log_filtered_avg_success_rates, pred_power_log)
r2_linear = r2_score(log_filtered_avg_success_rates, pred_linear)

print(f"Log-Log Inverse Exponential Model:")
print(f"Original formula: y = {a_exp_log:.4f} * exp(-{b_exp_log:.4f} * x) + {c_exp_log:.4f}")
print(f"MSE = {mse_exp_log:.4f}, R^2 = {r2_exp_log:.4f}\n")


print(f"Log-Log Power Law Model:")
print(f"Formula: ln(y) = {a_power_log:.4f} * ln(x) + {b_power_log:.4f}")
print(f"MSE = {mse_power_log:.4f}, R^2 = {r2_power_log:.4f}\n")

print(f"Log-Log Linear Model:")
print(f"Formula: ln(y) = {m_linear:.4f} * x + {c_linear:.4f}")
print(f"MSE = {mse_linear:.4f}, R^2 = {r2_linear:.4f}\n")

x_vals_log = np.linspace(min(log_filtered_counties), max(log_filtered_counties), 500)
y_vals_exp_log = inverse_exponential(x_vals_log, a_exp_log, b_exp_log, c_exp_log)
y_vals_power_log = power_law(x_vals_log, a_power_log, b_power_log)
y_vals_linear = linear_model(x_vals_log, m_linear, c_linear)

plt.figure(figsize=(10, 6))
plt.scatter(log_filtered_counties, log_filtered_avg_success_rates, color='blue', label="Log-Log Data Points")
plt.plot(x_vals_log, y_vals_exp_log, "r--", label="Log-Log Inverse Exponential Fit")
plt.plot(x_vals_log, y_vals_power_log, "m--", label="Log-Log Power Law Fit")
plt.plot(x_vals_log, y_vals_linear, "b--", label="Log-Log Linear Fit")

plt.xlabel("Log(Number of Counties)")
plt.ylabel("Log(Average Success Rate)")
plt.title("Log-Log Model Comparisons")
plt.legend()
plt.show()
# Out:
# Log-Log Inverse Exponential Model:
# Original formula: y = 18.3153 * exp(-0.0943 * x) + -16.8665
# MSE = 0.1520, R^2 = 0.8182
#
# Log-Log Power Law Model:
# Formula: ln(y) = -6.0801 * ln(x) + 4.4092
# MSE = 0.1528, R^2 = 0.8172
#
# Log-Log Linear Model:
# Formula: ln(y) = -0.9196 * x + -0.9343
# MSE = 0.1534, R^2 = 0.8164

# %% [markdown]
# $y = \frac{a}{x^b}+c$  THUS $ln(y) = ln(\frac{a}{x^b}+c)$     HENCE     $ln(y) = log(c) - Bln(x)$

# %%
#LOG TRANSFORM 

#define inverse polynomial 
def inverse_polynomial(x, a, b, c):
    return (a / (x ** b)) + c

#extarct data
counties = [state_data["nodes"] for state_data in graph_data.values()]
avg_success_rates = [state_data["avg_success_rate"] for state_data in graph_data.values()]
states = list(graph_data.keys())

#apply log transformations 
log_counties = np.log(counties)
log_avg_success_rates = np.log(avg_success_rates)

#fit model to original space 
params_poly, _ = curve_fit(inverse_polynomial, counties, avg_success_rates, maxfev=10000)
a_poly, b_poly, c_poly = params_poly

#generate in normal space then log transform them 
pred_poly = inverse_polynomial(counties, a_poly, b_poly, c_poly)
log_pred_poly = np.log(pred_poly)

#transform log-log space for plotting 
x_vals = np.linspace(min(counties), max(counties), 500)
y_vals_poly = inverse_polynomial(x_vals, a_poly, b_poly, c_poly)

#generate x values for plotting the fitted curve 
log_x_vals = np.log(x_vals)
log_y_vals_poly = np.log(y_vals_poly)

#plot log-log transformed data and fits
plt.figure(figsize=(10, 6))
plt.scatter(log_counties, log_avg_success_rates, color='blue', label="Log-Log Data Points")
plt.plot(log_x_vals, log_y_vals_poly, "g--", label="Log-Log Inverse Polynomial Fit")

# Formula text for inverse polynomial (in original space)
formula_text_poly = f"ln(y) = {np.log(a_poly):.2f} - ln(x + {b_poly:.2f})"
#formula_text_poly = f"y = {a_poly:.2f} / (x + {b_poly:.2f}) + {c_poly:.2f}"
plt.text(0.05, 0.95, formula_text_poly, transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color="green")

plt.ylim(-10, -5)
plt.xlabel("Log(Number of Counties)")
plt.ylabel("Log(Average Success Rate)")
plt.title("Log-Log Inverse Polynomial Fit")
plt.legend()
plt.show()
# Out:
# /var/folders/t1/h9s22qms3r9080_ljhqwn8z40000gn/T/ipykernel_43513/3200105608.py:22: RuntimeWarning: invalid value encountered in log
#   log_pred_poly = np.log(pred_poly)
# /var/folders/t1/h9s22qms3r9080_ljhqwn8z40000gn/T/ipykernel_43513/3200105608.py:30: RuntimeWarning: invalid value encountered in log
#   log_y_vals_poly = np.log(y_vals_poly)

# %% [markdown]
# MEAN SQUARED ERROR (MSE) $MSE = \frac{1}{n} \sum_{i=1}^{n}(ln(y_i)-ln(\hat{y_i}))^2$

# %%
from sklearn.metrics import mean_squared_error

mse_poly_log = mean_squared_error(log_avg_success_rates, log_pred_poly)
print(f"Log-Log Inverse Polynomial Model: MSE = {mse_poly_log:.4f}")
# Out:
# Log-Log Inverse Polynomial Model: MSE = 0.7068

# %% [markdown]
# $R^2= 1- \frac{\sum(y-\hat{y})^2}{\sum(y-\bar{y})^2}$

# %%
from sklearn.metrics import r2_score

r2_poly_log = r2_score(log_avg_success_rates, log_pred_poly)
print(f"Log-Log Inverse Polynomial Model: R² = {r2_poly_log:.4f}")
# Out:
# Log-Log Inverse Polynomial Model: R² = 0.1543

# %% [markdown]
# MEAN ABSOLUTE ERROR $MAE = \frac{1}{n}\sum_{i=1}^{n}|ln(y_i)-ln(\hat{y_i})|$

# %%
from sklearn.metrics import mean_absolute_error

mae_poly_log = mean_absolute_error(log_avg_success_rates, log_pred_poly)
print(f"Log-Log Inverse Polynomial Model: MAE = {mae_poly_log:.4f}")
# Out:
# Log-Log Inverse Polynomial Model: MAE = 0.4730

# %% [markdown]
# RESIDUALS = $ln(y_i)-ln(\hat{y_i})$

# %%
plt.figure(figsize=(10, 6))
residuals = log_avg_success_rates - log_pred_poly
plt.scatter(log_counties, residuals, color='purple')
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.xlabel("Log(Number of Counties)")
plt.ylabel("Residuals")
plt.title("Residuals Plot (Log-Log Inverse Polynomial Fit)")
plt.show()

# %% [markdown]
# LOG Y versus Plain x

# %%
counties = [state_data["nodes"] for state_data in graph_data.values()]
avg_success_rates = [state_data["avg_success_rate"] for state_data in graph_data.values()]
states = list(graph_data.keys())

#log(y)
log_avg_success_rates = np.log(avg_success_rates)

plt.figure(figsize=(10, 6))
plt.scatter(counties, log_avg_success_rates, color='blue', label="Data Points")

plt.xlabel("Number of Counties")
plt.ylabel("Log(Average Success Rate)")
plt.title("Number of Counties vs. Log(Average Success Rate)")

plt.legend()
plt.show()

# %%
def inverse_polynomial(x, a, b, c):
    return a / (x + b) + c

# Fit the inverse polynomial model to the original (non-log-transformed) data
params_poly, _ = curve_fit(inverse_polynomial, counties, log_avg_success_rates, maxfev=10000)
a_poly, b_poly, c_poly = params_poly

# Generate x values for plotting the fitted curve
x_vals = np.linspace(min(counties), max(counties), 500)
y_vals_poly = inverse_polynomial(x_vals, a_poly, b_poly, c_poly)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(counties, log_avg_success_rates, color='blue', label="Data Points")

# Plot the inverse polynomial fit
plt.plot(x_vals, y_vals_poly, "g--", label="Inverse Polynomial Fit")

# Display formula
formula_text_poly = f"ln(y) = {np.log(a_poly):.2f} - ln(x + {b_poly:.2f})"
#formula_text = f"log(y) = {a_poly:.2f} / (x + {b_poly:.2f}) + {c_poly:.2f}"
plt.text(0.05, 0.95, formula_text, transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color="green")

plt.xlabel("Number of Counties")
plt.ylabel("Log(Average Success Rate)")
plt.title("log(y) vs. plain x")

plt.legend()
plt.show()

# %%
#generate predictions
pred_poly_log = inverse_polynomial(counties, a_poly, b_poly, c_poly)

#MSE
mse_poly_log = mean_squared_error(log_avg_success_rates, pred_poly_log)

#R-squared value
r2_poly_log = r2_score(log_avg_success_rates, pred_poly_log)

print(f"Log-Transformed Inverse Polynomial Model: MSE = {mse_poly_log:.4f}, R² = {r2_poly_log:.4f}")
# Out:
# Log-Transformed Inverse Polynomial Model: MSE = 0.1495, R² = 0.8212

# %% [markdown]
# 1/Success Rate

# %%
def inverse_polynomial(x, a, b, c):
    return a / (x + b) + c

counties = np.array([state_data["nodes"] for state_data in graph_data.values()])
avg_success_rates = np.array([state_data["avg_success_rate"] for state_data in graph_data.values()])
states = list(graph_data.keys())

#epsilon to prevent division errors
epsilon = 1e-6
inverse_success_rates = 1 / (avg_success_rates + epsilon)

#apply log transformation to 1/success probability
log_inverse_success_rates = np.log(inverse_success_rates )

#provide initial parameter guesses for better convergence
initial_guess = [max(log_inverse_success_rates), 1, min(log_inverse_success_rates)]

#fit model
params_poly, _ = curve_fit(inverse_polynomial, counties, log_inverse_success_rates, p0=initial_guess, maxfev=10000)
a_poly, b_poly, c_poly = params_poly

#generate x values 
x_vals = np.linspace(min(counties), max(counties), 500)
y_vals_poly = inverse_polynomial(x_vals, a_poly, b_poly, c_poly)

# Plot 
plt.figure(figsize=(10, 6))
plt.scatter(counties, log_inverse_success_rates, color='blue', label="Data Points")
plt.plot(x_vals, y_vals_poly, "g--", label="Inverse Polynomial Fit")

formula_text_poly = f"ln(1/y) = {a_poly:.2f} / (x + {b_poly:.2f}) + {c_poly:.2f}"
plt.text(0.05, 0.95, formula_text_poly, transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color="green")

plt.xlabel("Number of Counties")
plt.ylabel("Log(1/Success Rate)")
plt.title("Log(1/Success Rate) vs. Number of Counties")

plt.legend()
plt.show()

# %%
pred_poly_log = inverse_polynomial(counties, a_poly, b_poly, c_poly)
mse_poly_log = mean_squared_error(log_inverse_success_rates, pred_poly_log)
r2_poly_log = r2_score(log_inverse_success_rates, pred_poly_log)

print(f"Log(1/Success Rate) Inverse Polynomial Model: MSE = {mse_poly_log:.4f}, R² = {r2_poly_log:.4f}")
# Out:
# Log(1/Success Rate) Inverse Polynomial Model: MSE = 0.1487, R² = 0.8214
